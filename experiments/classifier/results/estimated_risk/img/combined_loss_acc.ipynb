# %%
import pandas as pd
import numpy as np
import importlib
import sys
import os
# Add the folder and subfolder to the system path
sys.path.append(os.path.abspath(os.path.join('../../../')))
from AIedes.models import classificator_model



year="2020"
# load all the models and results in the current ending pkl files
dir = './'
files = [f for f in os.listdir(dir) if f.endswith('.pkl') and f.startswith('results_and_models_')]
print(f"Found {len(files)} files matching the criteria.")
# load the models and results for each input variable example of file results_and_models_T_TP_2020_[20, 20, 20]_temp_tp
res_all = []
for file in files:
    input_var = file.split('_')[-1]  # Extract the input variable from the filename
    print(f"Processing file: {file} with input variable: {input_var}")
    if input_var == "temp.pkl":
        res = pd.read_pickle(dir + file)
        res["input_var"] = "temp"
    elif input_var == "tp.pkl":
        res = pd.read_pickle(dir + file)
        res["input_var"] = "temp_tp"
    elif input_var == "4Bio.pkl":
        res = pd.read_pickle(dir + file)
        res["input_var"] = "4Bio"
    res_all.append(res)
# Concatenate all results into a single DataFrame
merged_results = pd.concat(res_all, ignore_index=True)
merged_results
# Out:
# Found 22 files matching the criteria.
# Processing file: results_and_models_2020_[]_temp.pkl with input variable: temp.pkl
# Processing file: results_and_models_2020_[10]_temp.pkl with input variable: temp.pkl
# Processing file: results_and_models_2020_[30]_temp.pkl with input variable: temp.pkl
# Processing file: results_and_models_2020_[10, 10]_temp.pkl with input variable: temp.pkl
# Processing file: results_and_models_2020_[]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[10]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[30]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[10, 10]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[30, 30]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[10, 10, 10]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[30, 30, 30]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[40, 40]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[40, 40, 40]_temp_tp.pkl with input variable: tp.pkl
# Processing file: results_and_models_2020_[]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[10]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[30]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[10, 10]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[30, 30]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[10, 10, 10]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[30, 30, 30]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[40, 40]_4Bio.pkl with input variable: 4Bio.pkl
# Processing file: results_and_models_2020_[40, 40, 40]_4Bio.pkl with input variable: 4Bio.pkl
#    hidden_layers        ACC_test_list          TPR_test_list  \
# 0             []  [88.60409737689795]  [0.21443728849211505]
# 1           [10]     [90.04647405009]                  [0.0]
# 2           [30]  [91.35737848670837]  [0.42210013796346135]
# 3       [10, 10]  [91.13051960167915]  [0.37559469675878665]
# 4             []  [89.10659717464411]   [0.8254192250141892]
# 5           [10]  [95.16937442321566]   [0.9462360043341417]
# 6           [30]  [97.54906897308862]   [0.9619188896341778]
# 7       [10, 10]   [97.2364704347984]   [0.9581110365822197]
# 8       [30, 30]  [98.75761272780402]   [0.9842165006965585]
# 9   [10, 10, 10]  [97.71770874433946]    [0.954955884629276]
# 10  [30, 30, 30]  [99.02522415139444]    [0.989541303338321]
# 11      [40, 40]  [99.09522245096404]   [0.9841855425416646]
# 12  [40, 40, 40]  [99.18759049013669]   [0.9924229915897013]
# 13            []  [87.21540490879585]   [0.7702750116093081]
# 14          [10]  [92.27393768500436]   [0.9114983746968681]
# 15          [30]  [94.30504400482724]   [0.9281332232598937]
# 16      [10, 10]   [93.9562081392834]   [0.9215829936535782]
# 17      [30, 30]  [96.51494315114515]   [0.9540168205974924]
# 18  [10, 10, 10]  [95.05166501851488]   [0.9207574428564057]
# 19  [30, 30, 30]  [97.25768454209721]    [0.950959702801713]
# 20      [40, 40]  [96.80327341104686]   [0.9654068417522316]
# 21  [40, 40, 40]  [97.68766230442986]   [0.9678473762963727]
#
#            TNR_test_list           FPR_test_list           FNR_test_list  \
# 0   [0.9602784692398173]   [0.03972153076018273]    [0.7855627115078849]
# 1                  [1.0]                   [0.0]                   [1.0]
# 2   [0.9679001285663484]   [0.03209987143365156]    [0.5778998620365386]
# 3   [0.9705213775747463]  [0.029478622425253714]    [0.6244053032412133]
# 4   [0.9219531024303321]   [0.07804689756966782]   [0.17458077498581084]
# 5   [0.9542616388173403]    [0.0457383611826597]  [0.053763995665858315]
# 6   [0.9818762912125928]  [0.018123708787407232]    [0.0380811103658222]
# 7   [0.9790711280615849]  [0.020928871938415076]    [0.0418889634177803]
# 8   [0.9891568487979433]  [0.010843151202056716]  [0.015783499303441514]
# 9   [0.9876322772195505]  [0.012367722780449555]  [0.045044115370723906]
# 10  [0.9905867415681239]   [0.00941325843187617]  [0.010458696661678963]
# 11  [0.9941359830452103]  [0.005864016954789655]  [0.015814457458335485]
# 12  [0.9916184978114629]  [0.008381502188537067]  [0.007577008410298746]
# 13  [0.9200886582070746]    [0.0799113417929253]   [0.22972498839069191]
# 14  [0.9280283259572877]   [0.07197167404271228]   [0.08850162530313194]
# 15    [0.95006906697676]  [0.049930933023240004]   [0.07186677674010629]
# 16  [0.9480213342914505]    [0.0519786657085495]   [0.07841700634642175]
# 17  [0.9703873819852932]  [0.029612618014706774]   [0.04598317940250761]
# 18  [0.9645185097070055]  [0.035481490292994494]   [0.07924255714359424]
# 19  [0.9827478217804957]   [0.01725217821950432]   [0.04904029719828698]
# 20   [0.969268229918989]   [0.03073177008101107]   [0.03459315824776843]
# 21   [0.981124929901267]     [0.018875070098733]  [0.032152623703627266]
#
#     MEAN_ACC_test  MEAN_TPR_test  MEAN_TNR_test  MEAN_FPR_test  ...  \
# 0       88.604097       0.214437       0.960278       0.039722  ...
# 1       90.046474       0.000000       1.000000       0.000000  ...
# 2       91.357378       0.422100       0.967900       0.032100  ...
# 3       91.130520       0.375595       0.970521       0.029479  ...
# 4       89.106597       0.825419       0.921953       0.078047  ...
# 5       95.169374       0.946236       0.954262       0.045738  ...
# 6       97.549069       0.961919       0.981876       0.018124  ...
# 7       97.236470       0.958111       0.979071       0.020929  ...
# 8       98.757613       0.984217       0.989157       0.010843  ...
# 9       97.717709       0.954956       0.987632       0.012368  ...
# 10      99.025224       0.989541       0.990587       0.009413  ...
# 11      99.095222       0.984186       0.994136       0.005864  ...
# 12      99.187590       0.992423       0.991618       0.008382  ...
# 13      87.215405       0.770275       0.920089       0.079911  ...
# 14      92.273938       0.911498       0.928028       0.071972  ...
# 15      94.305044       0.928133       0.950069       0.049931  ...
# 16      93.956208       0.921583       0.948021       0.051979  ...
# 17      96.514943       0.954017       0.970387       0.029613  ...
# 18      95.051665       0.920757       0.964519       0.035481  ...
# 19      97.257685       0.950960       0.982748       0.017252  ...
# 20      96.803273       0.965407       0.969268       0.030732  ...
# 21      97.687662       0.967847       0.981125       0.018875  ...
#
#     num_params  num_epochs  test_ratio  val_ratio  learning_rate  random_seed  \
# 0           13         100         0.2        0.0          0.005           42
# 1          141         100         0.2        0.0          0.005           42
# 2          421         100         0.2        0.0          0.005           42
# 3          251         100         0.2        0.0          0.005           42
# 4           15         100         0.2        0.0          0.005           42
# 5          161         100         0.2        0.0          0.005           42
# 6          481         100         0.2        0.0          0.005           42
# 7          271         100         0.2        0.0          0.005           42
# 8         1411         100         0.2        0.0          0.005           42
# 9          381         100         0.2        0.0          0.005           42
# 10        2341         100         0.2        0.0          0.005           42
# 11        2281         100         0.2        0.0          0.005           42
# 12        3921         100         0.2        0.0          0.005           42
# 13           5         100         0.2        0.0          0.005           42
# 14          61         100         0.2        0.0          0.005           42
# 15         181         100         0.2        0.0          0.005           42
# 16         171         100         0.2        0.0          0.005           42
# 17        1111         100         0.2        0.0          0.005           42
# 18         281         100         0.2        0.0          0.005           42
# 19        2041         100         0.2        0.0          0.005           42
# 20        1881         100         0.2        0.0          0.005           42
# 21        3521         100         0.2        0.0          0.005           42
#
#                                       input_variables  input_size  \
# 0   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          12
# 1   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          12
# 2   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          12
# 3   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          12
# 4   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 5   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 6   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 7   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 8   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 9   [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 10  [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 11  [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 12  [TAVG_01, TAVG_02, TAVG_03, TAVG_04, TAVG_05, ...          14
# 13  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 14  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 15  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 16  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 17  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 18  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 19  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 20  [annual_temp, annual_prec, max_temp_warmest_mo...           4
# 21  [annual_temp, annual_prec, max_temp_warmest_mo...           4
#
#                                                 model  input_var
# 0   [AIedesClassificator(\n  (layers): ModuleList(...       temp
# 1   [AIedesClassificator(\n  (layers): ModuleList(...       temp
# 2   [AIedesClassificator(\n  (layers): ModuleList(...       temp
# 3   [AIedesClassificator(\n  (layers): ModuleList(...       temp
# 4   [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 5   [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 6   [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 7   [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 8   [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 9   [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 10  [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 11  [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 12  [AIedesClassificator(\n  (layers): ModuleList(...    temp_tp
# 13  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 14  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 15  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 16  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 17  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 18  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 19  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 20  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
# 21  [AIedesClassificator(\n  (layers): ModuleList(...       4Bio
#
# [22 rows x 40 columns]

# %%
merged_results["input_var"].unique()
# rename the input var "temp" to "Temp." and "temp_tp" to "Temp. + Prec."
merged_results["input_var"] = merged_results["input_var"].replace({"temp": "Temp.", "temp_tp": "Temp. + Prec.", "4Bio": "4Bio"})

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

res_t = merged_results[merged_results['input_var'] == 'Temp.'].reset_index(drop=True)
res_t_tp = merged_results[merged_results['input_var'] == 'Temp. + Prec.'].reset_index(drop=True)
res_4bio = merged_results[merged_results['input_var'] == '4Bio'].reset_index(drop=True)

# --- 1) GLOBAL STYLE FOR BOTH PANELS ---
sns.set_theme(
    style="whitegrid",
    context="paper",
    font_scale=1.2,
    rc={
        "axes.labelsize": 12,
        "axes.titlesize": 14,
        "xtick.labelsize": 10,
        "ytick.labelsize": 10,
        "legend.fontsize": 10,
        "grid.linewidth": 0.5,
        "grid.color": "0.8"
    }
)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# ================== LEFT PANEL: LOSS CURVES ==================
model_index = 3
res_df = res_t.copy()
if model_index < len(res_df):
    md = res_df.iloc[model_index]
    epochs = range(1, len(md["train_losses"][5:]) + 1)

    axs[0].plot(epochs, md["train_losses"][5:], label='Training Loss',
                color='#2E86AB', linewidth=2, alpha=0.85)
    axs[0].plot(epochs, md["test_losses"][6:],   # shift for alignment
                label='Testing Loss', color='#F24236',
                linewidth=2, linestyle='--', alpha=0.85)

    axs[0].set_xscale("log")
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Loss')
    axs[0].set_ylim(0.1, 1.2 * max(max(md["train_losses"][5:]), max(md["test_losses"][6:])))
    axs[0].legend(frameon=True, loc="best")
else:
    axs[0].text(.5, .5, "Model index out of range",
                ha='center', va='center')

# ================== RIGHT PANEL: PARAMS vs ACCURACY ==================
# Include all three input variable types
res_t['input_var'] = 'Temp.'
merged = pd.concat([res_t, res_t_tp, res_4bio], ignore_index=True)
merged["number of hidden layers"] = merged["hidden_layers"].apply(len)

# Updated palette and labels to include 4Bio
palette = {"Temp.": "#1f77b4", "Temp. + Prec.": "#ff7f0e", "4Bio": "#2ca02c"}
markers = {0: "o", 1: "s", 2: "D", 3: "X", 4: "P"}
# Nice display names for legend
input_labels = {
    "Temp.": "Temperature",
    "Temp. + Prec.": "Temperature + Precipitation",
    "4Bio": "4 Bioclimatic Variables"
}
# Build depth labels from the data present
depth_labels = {
    d: (f"{d} layer" if d == 1 else ("Logistic Regression" if d == 0 else f"{d} layers"))
    for d in sorted(merged["number of hidden layers"].unique())
}

# Display columns used only for plotting (controls legend labels)
merged["Input Variables"] = merged["input_var"].map(input_labels)
merged["Hidden layers"] = merged["number of hidden layers"].map(depth_labels)

# Orders to control legend order - now includes 4Bio
hue_order = [input_labels["4Bio"], input_labels["Temp. + Prec."], input_labels["Temp."]]
style_order = [depth_labels[d] for d in sorted(depth_labels)]

# Palettes/markers mapped to the new display names
palette_disp = {input_labels[k]: v for k, v in palette.items()}
markers_disp = {depth_labels[k]: v for k, v in markers.items() if k in depth_labels}

ax = axs[1]
sns.scatterplot(
    data=merged,
    x="num_params", y="MEAN_ACC_test",
    hue="Input Variables", hue_order=hue_order, palette=palette_disp,
    style="Hidden layers", style_order=style_order, markers=markers_disp,
    s=100, edgecolor="k", ax=ax
)
sns.lineplot(
    data=merged,
    x="num_params", y="MEAN_ACC_test",
    hue="Input Variables", hue_order=hue_order, palette=palette_disp,
    linewidth=1.5, dashes=True, legend=False, ax=ax
)
for (var, depth), grp in merged.groupby(["input_var", "number of hidden layers"]):
    ax.errorbar(
        grp["num_params"], grp["MEAN_ACC_test"],
        yerr=grp["STD_ACC_test"], fmt="none",
        capsize=4, ecolor=palette[var], alpha=0.8
    )

ax.set_xscale("log")
ax.set_xlabel("Number of Parameters (log scale)")
ax.set_ylabel("Test Accuracy")

from matplotlib.lines import Line2D

# Remove auto legend
leg = ax.get_legend()
if leg is not None:
    leg.remove()

# Filled markers for Inputs (hue)
hue_labels = hue_order
hue_handles = [
    Line2D([0], [0], marker='o', linestyle='',
           markersize=8,
           markerfacecolor=palette_disp[name],
           markeredgecolor='black',
           label=name)
    for name in hue_labels
]

# Hollow markers for Hidden layers (style)
style_labels = style_order
style_handles = [
    Line2D([0], [0], marker=markers_disp[name], linestyle='',
           markersize=8,
           markerfacecolor='none',
           markeredgecolor='black',
           label=name)
    for name in style_labels
]

x_leg = 0.6

# First legend (top)
leg_inputs = ax.legend(
    handles=hue_handles, labels=hue_labels,
    title="Input Variables", frameon=True,
    loc='upper left', bbox_to_anchor=(x_leg, 0.5),
    borderaxespad=0., ncol=1
)
ax.add_artist(leg_inputs)

# Second legend directly below the first (same x anchor)
fig.canvas.draw()  # ensure we have a renderer
renderer = fig.canvas.get_renderer()
bbox_disp = leg_inputs.get_window_extent(renderer=renderer)
bbox_axes = ax.transAxes.inverted().transform_bbox(bbox_disp)
gap = 0.02  # small vertical gap in Axes coords
y2 = bbox_axes.y0 - gap

ax.legend(
    handles=style_handles, labels=style_labels,
    title="Hidden layers", frameon=True,
    loc='upper left', bbox_to_anchor=(x_leg, y2),
    borderaxespad=0., ncol=1
)

# --- 3) APPLY IDENTICAL SPINE & GRID TWEAKS TO BOTH AXES ---
for a in axs:
    # remove top/right spines
    sns.despine(ax=a, trim=False)
    # thicken bottom/left
    a.spines['left'].set_linewidth(1.3)
    a.spines['bottom'].set_linewidth(1.3)
    # ensure grid
    a.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)

# Add panel labels ("a", "b")
axs[0].text(
    0.05, 1.0, "a", transform=axs[0].transAxes,
    fontsize=16, fontweight='bold', va='top', ha='right'
)
axs[1].text(
    0.05, 1.0, "b", transform=axs[1].transAxes,
    fontsize=16, fontweight='bold', va='top', ha='right'
)

fig.tight_layout()
fig.savefig("./combined_loss_acc.pdf", dpi=300,
            bbox_inches='tight', facecolor='white')
plt.show()
